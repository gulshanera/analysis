# %%
# import and clean sensirion data
# xlsx file creates sometime some issue so i have concerted them into csv format
import pandas as pd
import os
import numpy as np

#cutting required data timeline from data
d1 = pd.to_datetime("2022-11-27", format="%Y-%m-%d")
d2 =  pd.to_datetime("2022-12-23", format="%Y-%m-%d")

df = pd.read_csv("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/s.csv", dtype="str")
df['datetime'] = pd.to_datetime(df['datetime'])
df["datetime"] = pd.to_datetime(df["datetime"], format="%d-%m-%Y %H:%M")

df[df.columns[1:]] = df[df.columns[1:]].astype("float64")

mask = (df.datetime >= d1) & (df.datetime <= d2)

df=df[mask].reset_index(drop=True)
df
# Out:
#                 datetime     S1     S2     S3
# 0    2022-12-22 23:47:15    NaN    NaN   36.0
# 1    2022-12-22 23:47:14   39.0    NaN    NaN
# 2    2022-12-22 23:31:45    NaN    NaN   35.0
# 3    2022-12-22 23:31:43   37.0    NaN    NaN
# 4    2022-12-22 23:16:14    NaN    NaN   34.0
# ...                  ...    ...    ...    ...
# 5022 2022-11-27 21:29:36    NaN  165.0    NaN
# 5023 2022-11-27 21:29:36  163.0    NaN    NaN
# 5024 2022-11-27 21:15:08    NaN    NaN  178.0
# 5025 2022-11-27 21:15:07    NaN  183.0    NaN
# 5026 2022-11-27 21:15:06  180.0    NaN    NaN
#
# [5027 rows x 4 columns]

# %%
ql=df
ql['hour']=ql['datetime'].dt.hour
ql['date']=ql['datetime'].dt.date
ql=ql.groupby(['date','hour']).agg(np.mean).reset_index()
ql['date'] = ql['date'].astype(str)
ql['hour'] = ql['hour'].astype(str)
ql['datetime']=pd.to_datetime(ql['date'] + ' ' + ql['hour']+':'+'00'+':'+'00')
ql=ql.drop(['date','hour'], axis=1)
ql
# Out:
#          S1          S2          S3            datetime
# 0    168.00  174.000000  162.500000 2022-11-27 21:00:00
# 1     95.75   96.250000   99.000000 2022-11-27 22:00:00
# 2     58.75   61.666667   54.750000 2022-11-27 23:00:00
# 3     20.50   19.250000   20.000000 2022-11-28 00:00:00
# 4     16.00   14.666667   14.333333 2022-11-28 01:00:00
# ..      ...         ...         ...                 ...
# 565   83.00   79.000000   75.500000 2022-12-22 19:00:00
# 566   66.00   63.333333   66.000000 2022-12-22 20:00:00
# 567   44.00   40.000000   40.333333 2022-12-22 21:00:00
# 568   36.50   46.000000   35.750000 2022-12-22 22:00:00
# 569   34.75   33.000000   36.000000 2022-12-22 23:00:00
#
# [570 rows x 4 columns]

# %%
ql.to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/sensirion.xlsx", index=False)

# %%
# plantower sensor
#cutting required data timeline from data
d1 = pd.to_datetime("2022-11-27", format="%Y-%m-%d")
d2 =  pd.to_datetime("2022-12-23", format="%Y-%m-%d")

df = pd.read_csv("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/p.csv", dtype="str")
df['datetime'] = pd.to_datetime(df['datetime'])
df["datetime"] = pd.to_datetime(df["datetime"], format="%d-%m-%Y %H:%M")

df[df.columns[1:]] = df[df.columns[1:]].astype("float64")

mask = (df.datetime >= d1) & (df.datetime <= d2)

df=df[mask].reset_index(drop=True)
ql=df
ql['hour']=ql['datetime'].dt.hour
ql['date']=ql['datetime'].dt.date
ql=ql.groupby(['date','hour']).agg(np.mean).reset_index()
ql['date'] = ql['date'].astype(str)
ql['hour'] = ql['hour'].astype(str)
ql['datetime']=pd.to_datetime(ql['date'] + ' ' + ql['hour']+':'+'00'+':'+'00')
ql=ql.drop(['date','hour'], axis=1)
ql
# Out:
#              P1          P2          P3            datetime
# 0    204.500000  200.000000  186.000000 2022-11-27 21:00:00
# 1    124.500000  114.666667  103.500000 2022-11-27 22:00:00
# 2     76.250000   71.250000   69.333333 2022-11-27 23:00:00
# 3     35.000000   35.000000   35.000000 2022-11-28 00:00:00
# 4     25.666667   25.000000   21.000000 2022-11-28 01:00:00
# ..          ...         ...         ...                 ...
# 565   75.000000   76.500000   72.250000 2022-12-22 19:00:00
# 566   66.250000   68.666667   62.500000 2022-12-22 20:00:00
# 567   48.500000   48.000000   48.000000 2022-12-22 21:00:00
# 568   46.000000   47.500000   43.500000 2022-12-22 22:00:00
# 569   44.333333   43.000000   43.666667 2022-12-22 23:00:00
#
# [570 rows x 4 columns]

# %%
ql.to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/plantower.xlsx", index=False)

# %%
# plantower sensor
#cutting required data timeline from data
d1 = pd.to_datetime("2022-11-27", format="%Y-%m-%d")
d2 =  pd.to_datetime("2022-12-23", format="%Y-%m-%d")

df = pd.read_csv("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/h.csv", dtype="str")
df['datetime'] = pd.to_datetime(df['datetime'])
df["datetime"] = pd.to_datetime(df["datetime"], format="%d-%m-%Y %H:%M")

df[df.columns[1:]] = df[df.columns[1:]].astype("float64")

mask = (df.datetime >= d1) & (df.datetime <= d2)

df=df[mask].reset_index(drop=True)
ql=df
ql['hour']=ql['datetime'].dt.hour
ql['date']=ql['datetime'].dt.date
ql=ql.groupby(['date','hour']).agg(np.mean).reset_index()
ql['date'] = ql['date'].astype(str)
ql['hour'] = ql['hour'].astype(str)
ql['datetime']=pd.to_datetime(ql['date'] + ' ' + ql['hour']+':'+'00'+':'+'00')
ql=ql.drop(['date','hour'], axis=1)
ql
# Out:
#              H1          H2          H3            datetime
# 0    151.000000  160.000000  177.000000 2022-11-27 21:00:00
# 1     83.000000   85.750000  101.333333 2022-11-27 22:00:00
# 2     48.000000   55.000000   65.666667 2022-11-27 23:00:00
# 3     22.000000   19.666667   29.500000 2022-11-28 00:00:00
# 4     16.250000   17.333333   24.333333 2022-11-28 01:00:00
# ..          ...         ...         ...                 ...
# 564   54.000000   79.750000   73.000000 2022-12-22 19:00:00
# 565   44.333333   66.500000   76.000000 2022-12-22 20:00:00
# 566   29.000000   43.750000   38.750000 2022-12-22 21:00:00
# 567   23.000000   44.000000   42.333333 2022-12-22 22:00:00
# 568   24.333333   33.666667   30.000000 2022-12-22 23:00:00
#
# [569 rows x 4 columns]

# %%
ql.to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/honeywell.xlsx", index=False)

# %%
# importing BAM data removing higher values
df = pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/bam_jodhpur.xlsx")
df
# Out:
#                 datetime  BAMPM2.5    AT  AH
# 0    2022-09-28 00:00:00      49.0  25.9  91
# 1    2022-09-28 01:00:00      46.8  25.5  93
# 2    2022-09-28 02:00:00      48.8  25.2  93
# 3    2022-09-28 03:00:00      46.8  24.9  94
# 4    2022-09-28 04:00:00      44.2  24.6  94
# ...                  ...       ...   ...  ..
# 1994 2022-12-23 07:00:00      99.9  13.3  55
# 1995 2022-12-23 08:00:00     110.6  13.1  55
# 1996 2022-12-23 09:00:00     115.7  14.0  53
# 1997 2022-12-23 10:00:00     117.4  15.9  48
# 1998 2022-12-23 11:00:00     120.3  17.7  45
#
# [1999 rows x 4 columns]

# %%
# selecting BAM data between required dates
d1 = pd.to_datetime("2022-11-27", format="%Y-%m-%d")
d2 =  pd.to_datetime("2022-12-23", format="%Y-%m-%d")

df['datetime'] = pd.to_datetime(df['datetime'])
df["datetime"] = pd.to_datetime(df["datetime"], format="%d-%m-%Y %H:%M")

df[df.columns[1:]] = df[df.columns[1:]].astype("float64")

mask = (df.datetime >= d1) & (df.datetime <= d2)

df=df[mask].reset_index(drop=True)
df
# Out:
#                datetime  BAMPM2.5    AT    AH
# 0   2022-11-27 13:00:00   99999.9  29.3  19.0
# 1   2022-11-27 14:00:00      27.8  29.1  19.0
# 2   2022-11-27 15:00:00   99999.9  30.3  17.0
# 3   2022-11-27 16:00:00   99999.9  30.9  17.0
# 4   2022-11-27 17:00:00       4.5  28.9  19.0
# ..                  ...       ...   ...   ...
# 606 2022-12-22 20:00:00      81.1  20.1  39.0
# 607 2022-12-22 21:00:00      67.6  19.5  38.0
# 608 2022-12-22 22:00:00      46.3  18.4  35.0
# 609 2022-12-22 23:00:00      42.9  17.2  37.0
# 610 2022-12-23 00:00:00      35.5  16.5  38.0
#
# [611 rows x 4 columns]

# %%
# removing values more than 1000
ql=df
ql['BAMPM2.5'] = np.where(ql['BAMPM2.5'] > 1000, 0, ql['BAMPM2.5'])
ql['BAMPM2.5'] = np.where(ql['BAMPM2.5'] < 1, 0, ql['BAMPM2.5'])
ql=ql.replace(0,np.NaN)
ql
# Out:
#                datetime  BAMPM2.5    AT    AH
# 0   2022-11-27 13:00:00       NaN  29.3  19.0
# 1   2022-11-27 14:00:00      27.8  29.1  19.0
# 2   2022-11-27 15:00:00       NaN  30.3  17.0
# 3   2022-11-27 16:00:00       NaN  30.9  17.0
# 4   2022-11-27 17:00:00       4.5  28.9  19.0
# ..                  ...       ...   ...   ...
# 606 2022-12-22 20:00:00      81.1  20.1  39.0
# 607 2022-12-22 21:00:00      67.6  19.5  38.0
# 608 2022-12-22 22:00:00      46.3  18.4  35.0
# 609 2022-12-22 23:00:00      42.9  17.2  37.0
# 610 2022-12-23 00:00:00      35.5  16.5  38.0
#
# [611 rows x 4 columns]

# %%
ql.to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/jodhpur_BAM.xlsx", index=False)

# %%
# merging all datasets
# this is for inner join
sensirion=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/sensirion.xlsx")
plantower=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/plantower.xlsx")
honeywell=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/honeywell.xlsx")
bam=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/jodhpur_BAM.xlsx")
from functools import reduce
df=reduce(lambda x,y: pd.merge(x,y, on='datetime', how='inner'), [bam,sensirion,plantower,honeywell])
df
# Out:
#                datetime  BAMPM2.5    AT  AH      S1          S2          S3  \
# 0   2022-11-27 21:00:00       6.8  20.9  45  168.00  174.000000  162.500000
# 1   2022-11-27 22:00:00       8.0  20.1  48   95.75   96.250000   99.000000
# 2   2022-11-27 23:00:00       6.2  20.0  44   58.75   61.666667   54.750000
# 3   2022-11-28 00:00:00      10.6  19.8  39   20.50   19.250000   20.000000
# 4   2022-11-28 01:00:00       5.8  19.8  33   16.00   14.666667   14.333333
# ..                  ...       ...   ...  ..     ...         ...         ...
# 564 2022-12-22 19:00:00      95.3  20.9  39   83.00   79.000000   75.500000
# 565 2022-12-22 20:00:00      81.1  20.1  39   66.00   63.333333   66.000000
# 566 2022-12-22 21:00:00      67.6  19.5  38   44.00   40.000000   40.333333
# 567 2022-12-22 22:00:00      46.3  18.4  35   36.50   46.000000   35.750000
# 568 2022-12-22 23:00:00      42.9  17.2  37   34.75   33.000000   36.000000
#
# ...

# %%
df.to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one.xlsx", index=False)

# %%
df.isnull().sum()
# Out:
# datetime     0
# BAMPM2.5     7
# AT           0
# AH           0
# S1          37
# S2          34
# S3          33
# P1          32
# P2          31
# P3          32
# H1          30
# H2          33
# H3          37
# dtype: int64

# %%
# This is for outer join
sensirion=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/sensirion.xlsx")
plantower=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/plantower.xlsx")
honeywell=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/honeywell.xlsx")
bam=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/jodhpur_BAM.xlsx")
from functools import reduce
df=reduce(lambda x,y: pd.merge(x,y, on='datetime', how='outer'), [bam,sensirion,plantower,honeywell])
df
# Out:
#                datetime  BAMPM2.5    AT  AH     S1         S2         S3  \
# 0   2022-11-27 13:00:00       NaN  29.3  19    NaN        NaN        NaN
# 1   2022-11-27 14:00:00      27.8  29.1  19    NaN        NaN        NaN
# 2   2022-11-27 15:00:00       NaN  30.3  17    NaN        NaN        NaN
# 3   2022-11-27 16:00:00       NaN  30.9  17    NaN        NaN        NaN
# 4   2022-11-27 17:00:00       4.5  28.9  19    NaN        NaN        NaN
# ..                  ...       ...   ...  ..    ...        ...        ...
# 606 2022-12-22 20:00:00      81.1  20.1  39  66.00  63.333333  66.000000
# 607 2022-12-22 21:00:00      67.6  19.5  38  44.00  40.000000  40.333333
# 608 2022-12-22 22:00:00      46.3  18.4  35  36.50  46.000000  35.750000
# 609 2022-12-22 23:00:00      42.9  17.2  37  34.75  33.000000  36.000000
# 610 2022-12-23 00:00:00      35.5  16.5  38    NaN        NaN        NaN
#
#             P1         P2         P3         H1         H2         H3
# ...

# %%
df.to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one_outer.xlsx", index=False)

# %%
import pandas as pd
import os
import numpy as np
df=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one_outer.xlsx")
ndf=df.dropna()
ndf
# Out:
#                datetime  BAMPM2.5    AT  AH         S1         S2         S3  \
# 0   2022-11-29 00:00:00      41.0  20.8  30  28.750000  29.000000  26.666667
# 1   2022-11-29 01:00:00      47.8  19.8  32  31.000000  36.000000  36.000000
# 2   2022-11-29 02:00:00      51.4  18.8  35  44.500000  44.000000  42.000000
# 3   2022-11-29 03:00:00      73.5  18.4  38  60.000000  61.000000  57.000000
# 5   2022-11-29 05:00:00      72.9  17.4  43  62.666667  60.750000  60.666667
# ..                  ...       ...   ...  ..        ...        ...        ...
# 570 2022-12-22 19:00:00      81.1  20.9  39  83.000000  79.000000  75.500000
# 571 2022-12-22 20:00:00      67.6  20.1  39  66.000000  63.333333  66.000000
# 572 2022-12-22 21:00:00      46.3  19.5  38  44.000000  40.000000  40.333333
# 573 2022-12-22 22:00:00      42.9  18.4  35  36.500000  46.000000  35.750000
# 574 2022-12-22 23:00:00      35.5  17.2  37  34.750000  33.000000  36.000000
#
# ...

# %%
df.describe().to_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/summary.xlsx")

# %%
# for missing data percentage
df.isnull().sum() * 100 / len(df)
# Out:
# datetime    0.000000
# BAMPM2.5    1.215278
# AT          0.000000
# AH          0.000000
# S1          6.423611
# S2          5.902778
# S3          5.729167
# P1          5.555556
# P2          5.381944
# P3          5.555556
# H1          5.208333
# H2          5.729167
# H3          6.423611
# dtype: float64

# %%
# plotting R2 and robust regression for BAM and rest of these sensors
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# creating subdata for analysing R2 between two variables
ndf=df[['datetime','BAMPM2.5','S1']]
# removing rows with missing data points
ndf=ndf.dropna()
# Fit a linear regression model to the data
x = ndf['BAMPM2.5'].values.reshape(-1, 1)
y = ndf['S1'].values
model = LinearRegression().fit(x, y)

# Calculate R^2
r2 = r2_score(y, model.predict(x))

# Create a new figure
fig, ax = plt.subplots()

# Plot the data points
ax.scatter(x, y)

# Plot the regression line
line_x = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
line_y = model.predict(line_x)
ax.plot(line_x, line_y, color='red')

# Add a label showing the R^2 value
ax.text(0.05, 0.95, f'R^2 = {r2:.2f}', transform=ax.transAxes)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import RANSACRegressor

# Fit a RANSAC regression model to the data
# creating subdata for analysing R2 between two variables
ndf=df[['datetime','BAMPM2.5','S1']]
# removing rows with missing data points
ndf=ndf.dropna()
# Fit a linear regression model to the data
x = ndf['BAMPM2.5'].values.reshape(-1, 1)
y = ndf['S1'].values
model = RANSACRegressor().fit(x, y)

# Create a new figure
fig, ax = plt.subplots()

# Plot the data points
ax.scatter(x, y)

# Plot the regression line
line_x = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
line_y = model.predict(line_x)
ax.plot(line_x, line_y, color='red')

# Show the plot
plt.show()

# %%
from sklearn.metrics import r2_score

# Fit a robust regression model to the data
# creating subdata for analysing R2 between two variables
ndf=df[['datetime','BAMPM2.5','S1']]
# removing rows with missing data points
ndf=ndf.dropna()
# Fit a linear regression model to the data
x = ndf['BAMPM2.5'].values.reshape(-1, 1)
y = ndf['S1'].values
model = RANSACRegressor().fit(x, y)

# Calculate R^2
r2 = r2_score(y, model.predict(x))
print(f'R^2 = {r2:.2f}')
# Out:
# R^2 = 0.54

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RANSACRegressor
from sklearn.metrics import r2_score
import pandas as pd
import os
import numpy as np
# Load the data into a dataframe
# df = pd.read_csv('data.csv')
for i in range(4,13):
    # Extract the predictor and response variables
#     x = ndf[f"S{i}"].values.reshape(-1, 1)
    x=ndf.iloc[:,i].values.reshape(-1,1)
    y=ndf['BAMPM2.5'].values

    # Fit a linear regression model and a robust regression model to the data
    model_1 = LinearRegression().fit(x, y)
    y1_pred = model_1.predict(x)
    r2 = r2_score(y, model_1.predict(x))
#     mod = RANSACRegressor().fit(x, y)
#     y2_pred = mod.predict(x)

    # Calculate the predicted values for each model
#  rr2= r2_score(y, mod.predict(x))
    # Create a figure and a subplot
    fig, ax = plt.subplots()

    # Plot the data and the regression lines
    ax.scatter(x, y)
    ax.plot(x, y1_pred, label='Linear regression',color='red')
#     ax.plot(x, y2_pred, label='Robust regression')

    # Add a legend and labels
    ax.legend(loc='lower right')
    ax.set_xlabel(f"{ndf.columns[i]}")
    ax.set_ylabel('BAMPM2.5')
    # Add a label showing the R^2 value
    ax.text(0.05, 0.90, f'R^2 = {r2:.2f}', transform=ax.transAxes)
    plt.savefig('BAM vs' +ndf.columns[i] + '.jpg',dpi=400)
#     ax.text(0.05, 0.85, f'RR^2 = {rr2:.2f}', transform=ax.transAxes)
#     plt.savefig('{ndf.columns[i]}.jpg',dpi=400)
# Show the plot
plt.show()
# plt.savefig('"{ndf.columns[i]}".jpg',dpi=400)

# %%
from sklearn.metrics import r2_score

# Fit a robust regression model to the data
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values
model = RANSACRegressor().fit(x, y)

# Calculate R^2
r2 = r2_score(y, model.predict(x))
print(f'R^2 = {r2:.2f}')
# Out:
# R^2 = 0.60

# %%
# i am getting lower R2 in case of robust regression, so checking with older paper one dataset
import pandas as pd
import os
import numpy as np
df=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/paperone.xlsx")
ndf=df.dropna()
ndf
# Out:
#                 datetime     cbam  temp_cbam  humidity_cbam        gbam  \
# 110  2021-11-08 14:00:00  134.750     28.500          40.50  166.040000
# 111  2021-11-08 15:00:00  127.550     28.825          40.50  145.160000
# 112  2021-11-08 16:00:00  132.600     27.550          45.25  149.580000
# 113  2021-11-08 17:00:00  131.425     24.825          50.75  167.570000
# 114  2021-11-08 18:00:00  132.625     22.850          57.75  152.120000
# ...                  ...      ...        ...            ...         ...
# 2878 2022-03-03 22:00:00   74.750     20.550          74.50   80.336667
# 2879 2022-03-03 23:00:00   99.400     19.900          78.50   90.028500
# 2880 2022-03-04 00:00:00  104.250     19.275          81.75   96.753667
# 2881 2022-03-04 01:00:00   86.875     18.725          82.00  105.976000
# 2882 2022-03-04 02:00:00   85.100     18.125          83.00   87.850167
#
#          GPCS001     GPCS002     GPCS003     GPCS004     GPCS005     GPCS006  \
# ...

# %%
# plotting robust and linear regression for them
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RANSACRegressor
from sklearn.metrics import r2_score
import pandas as pd
import os
import numpy as np

# Load the data into a dataframe
# df = pd.read_csv('data.csv')
for i in range(5,14):
    # Extract the predictor and response variables
#     x = ndf[f"S{i}"].values.reshape(-1, 1)
    x=ndf.iloc[:,i].values.reshape(-1,1)
    y=ndf['cbam'].values

    # Fit a linear regression model and a robust regression model to the data
    model_1 = LinearRegression().fit(x, y)
    y1_pred = model_1.predict(x)
    r2 = r2_score(y, model_1.predict(x))
    mod = RANSACRegressor().fit(x, y)
    y2_pred = mod.predict(x)

    # Calculate the predicted values for each model
   
   
    
   
    rr2= r2_score(y, mod.predict(x))
    # Create a figure and a subplot
    fig, ax = plt.subplots()

    # Plot the data and the regression lines
    ax.scatter(x, y, label='Data')
    ax.plot(x, y1_pred, label='Linear regression')
#     ax.plot(x, y2_pred, label='Robust regression')

    # Add a legend and labels
    ax.legend(loc='lower right')
    ax.set_xlabel(f"{ndf.columns[i]}")
    ax.set_ylabel('BAMPM2.5')
    # Add a label showing the R^2 value
    ax.text(0.05, 0.90, f'R^2 = {r2:.2f}', transform=ax.transAxes)
#     ax.text(0.05, 0.85, f'RR^2 = {rr2:.2f}', transform=ax.transAxes)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cbam'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# plotting curves
import seaborn as sns
from matplotlib import pyplot as plt

sns.lmplot(x='BAMPM2.5',y='S1',hue='humidity_level',height=8,data=ndf,ci=None)

# %%
# creating humidity levels
# creating categorical variable for humidity
trial=ndf
def f(row):
    if row['AH']>0 and row['AH']<20:
        val = 'less than 20'
    elif row['AH']>=20 and row['AH']<30:
        val = '20-30'
    elif row['AH']>=30 and row['AH']<40:
        val = '30-40'
    elif row['AH']>=40 and row['AH']<50:
        val = '40-50'
    elif row['AH']>=50 and row['AH']<60:
        val = '50-60'
    else:
            val = 'Greater than 60'
    return val

trial['humidity_level'] = ndf.apply(f, axis=1)
trial  # trial has now category of humidity levels
# Out:
# C:\Users\gulsh\AppData\Local\Temp/ipykernel_13524/4197356390.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                datetime  BAMPM2.5    AT  AH         S1         S2         S3  \
# 0   2022-11-29 00:00:00      41.0  20.8  30  28.750000  29.000000  26.666667
# 1   2022-11-29 01:00:00      47.8  19.8  32  31.000000  36.000000  36.000000
# 2   2022-11-29 02:00:00      51.4  18.8  35  44.500000  44.000000  42.000000
# 3   2022-11-29 03:00:00      73.5  18.4  38  60.000000  61.000000  57.000000
# 5   2022-11-29 05:00:00      72.9  17.4  43  62.666667  60.750000  60.666667
# ..                  ...       ...   ...  ..        ...        ...        ...
# ...

# %%
# plotting curves
import seaborn as sns
from matplotlib import pyplot as plt
for i in range(4,13):
    a=ndf.iloc[:,i].values
    b=ndf['BAMPM2.5'].values
    fig, ax = plt.subplots(figsize=(15, 5))
    ax.set_xlabel(f"{ndf.columns[i]}")
    ax.set_ylabel('BAMPM2.5')
    sns.scatterplot(x=a,y=b,hue='humidity_level',data=ndf,ci=None)
    plt.savefig('BAM vs ' +ndf.columns[i] +'scatterplot at different humidity levels' + '.jpg',dpi=400)

# %%
# counting no of datapoints at different humidity levels
print(trial.groupby('humidity_level').size())
# Out:
# humidity_level
# 20-30              139
# 30-40              200
# 40-50              120
# 50-60               40
# Greater than 60      1
# less than 20        16
# dtype: int64

# %%
# correlation based on different humidity levels
trial.groupby('humidity_level')[['BAMPM2.5','S1']].corr().unstack().iloc[:,1]
# Out:
# humidity_level
# 20-30              0.797249
# 30-40              0.841565
# 40-50              0.901322
# 50-60              0.932180
# Greater than 60         NaN
# less than 20       0.925344
# Name: (BAMPM2.5, S1), dtype: float64

# %%
 fig, ax = plt.subplots(figsize=(15, 5))
sns.lineplot(x='datetime',y='S1',hue='humidity_level',data=ndf,ci=None)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='S1'>

# %%
 fig, ax = plt.subplots(figsize=(15, 5))
sns.scatterplot(x='datetime',y='S1',hue='humidity_level',data=ndf,ci=None)
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='S1'>

# %%
 fig, ax = plt.subplots(figsize=(15, 6))
gfg=sns.scatterplot(x='BAMPM2.5',y='AH',hue='humidity_level',data=ndf,ci=None)
gfg.set(xlabel ="Jodhpur BAM", ylabel = "Humidity", title ='PM2.5 Distribution at different humidity level')
plt.savefig('jodhpur site data humidity distribution.jpg',dpi=400)

# %%
fig, ax = plt.subplots(figsize=(18, 7))
plt.title('BAM and Sensirion PM2.5 variation over time(Hourly Average)', fontsize=15)
plt.plot(ndf.datetime,ndf['BAMPM2.5'],label="BAM",lw=3)
plt.plot(ndf.datetime,ndf.S1,label="Sensirion-1")
plt.plot(ndf.datetime,ndf.S2,label="Sensirion-2")
plt.plot(ndf.datetime,ndf.S3,label="Sensirion-3")
plt.legend()
plt.xlabel('Time', fontsize=15)
plt.ylabel('PM 2.5', fontsize=15)
plt.savefig('jodhpur bam and sensirion.jpg',dpi=400)
plt.show(block=False)

# %%
fig, ax = plt.subplots(figsize=(18, 7))
plt.title('BAM and Plantower PM2.5 variation over time(Hourly Average)', fontsize=15)
plt.plot(ndf.datetime,ndf['BAMPM2.5'],label="BAM",lw=3)
plt.plot(ndf.datetime,ndf.P1,label="Plantower-1")
plt.plot(ndf.datetime,ndf.P2,label="Plantower-2")
plt.plot(ndf.datetime,ndf.P3,label="Plantower-3")
plt.legend()
plt.xlabel('Time', fontsize=15)
plt.ylabel('PM 2.5', fontsize=15)
plt.savefig('jodhpur bam and Plantower.jpg',dpi=400)
plt.show(block=False)

# %%
plt.figure(figsize=(15,10))
plt.scatter(ndf['BAMPM2.5'],ndf.AH,s=4, label='BAM')
plt.scatter(ndf.S1, ndf.AH,s=4, label='S1')
plt.title('BAM & S1 PM2.5 vs Humidity', fontsize=15)
plt.ylabel('Humidity', fontsize=15)
plt.xlabel('PM2.5', fontsize=15)
plt.legend()

# %%
pip install pystan==2.19.1.1
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge prophet
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install httpstan
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
