# %%
import pandas as pd
import os
import numpy as np
df=pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one_outer.xlsx")
ndf=df.dropna()
ndf
# Out:
#                datetime  BAMPM2.5    AT  AH         S1         S2         S3  \
# 0   2022-11-29 00:00:00      41.0  20.8  30  28.750000  29.000000  26.666667
# 1   2022-11-29 01:00:00      47.8  19.8  32  31.000000  36.000000  36.000000
# 2   2022-11-29 02:00:00      51.4  18.8  35  44.500000  44.000000  42.000000
# 3   2022-11-29 03:00:00      73.5  18.4  38  60.000000  61.000000  57.000000
# 5   2022-11-29 05:00:00      72.9  17.4  43  62.666667  60.750000  60.666667
# ..                  ...       ...   ...  ..        ...        ...        ...
# 570 2022-12-22 19:00:00      81.1  20.9  39  83.000000  79.000000  75.500000
# 571 2022-12-22 20:00:00      67.6  20.1  39  66.000000  63.333333  66.000000
# 572 2022-12-22 21:00:00      46.3  19.5  38  44.000000  40.000000  40.333333
# 573 2022-12-22 22:00:00      42.9  18.4  35  36.500000  46.000000  35.750000
# 574 2022-12-22 23:00:00      35.5  17.2  37  34.750000  33.000000  36.000000
#
# ...

# %%
ndf.columns[1]
# Out:
# 'BAMPM2.5'

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RANSACRegressor
from sklearn.metrics import r2_score
import pandas as pd
import os
import numpy as np

# Load the data into a dataframe
# df = pd.read_csv('data.csv')
for i in range(4,13):
    # Extract the predictor and response variables
#     x = ndf[f"S{i}"].values.reshape(-1, 1)
    x=ndf.iloc[:,i].values.reshape(-1,1)
    y=ndf['BAMPM2.5'].values

    # Fit a linear regression model and a robust regression model to the data
    model_1 = LinearRegression().fit(x, y)
    y1_pred = model_1.predict(x)
    r2 = r2_score(y, model_1.predict(x))
    mod = RANSACRegressor().fit(x, y)
    y2_pred = mod.predict(x)

    # Calculate the predicted values for each model
   
   
    
   
    rr2= r2_score(y, mod.predict(x))
    # Create a figure and a subplot
    fig, ax = plt.subplots()

    # Plot the data and the regression lines
    ax.scatter(x, y, label='Data')
    ax.plot(x, y1_pred, label='Linear regression')
    ax.plot(x, y2_pred, label='Robust regression')

    # Add a legend and labels
    ax.legend(loc='lower right')
    ax.set_xlabel(f"{ndf.columns[i]}")
    ax.set_ylabel('BAMPM2.5')
    # Add a label showing the R^2 value
    ax.text(0.05, 0.90, f'R^2 = {r2:.2f}', transform=ax.transAxes)
    ax.text(0.05, 0.85, f'RR^2 = {rr2:.2f}', transform=ax.transAxes)
    plt.savefig('ndf.columns[i].jpg',dpi=400)

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install the robustreg library
#  pip install robustreg

# Import necessary libraries
import pandas as pd
from robust import robust
# Load the data into a dataframe
# df = pd.read_csv('data.csv')

# Extract the predictor and response variables
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data
model = robustreg.RobustLinearRegression().fit(x, y)

# Print the coefficients and intercept of the model
print(f'Coefficients: {model.coef_}')
print(f'Intercept: {model.intercept_}')

# Calculate the predicted values
y_pred = model.predict(x)

# Calculate the R^2 value
r2 = model.score(x, y)
print(f'R^2 = {r2:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25140/2240677313.py in <module>
#       4 # Import necessary libraries
#       5 import pandas as pd
# ----> 6 from robust import robust
#       7 # Load the data into a dataframe
#       8 # df = pd.read_csv('data.csv')
#
# ImportError: cannot import name 'robust' from 'robust' (C:\Users\gulsh\anaconda3\lib\site-packages\robust\__init__.py)

# %%
# Import necessary libraries
import pandas as pd
import statsmodels.api as smf

x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Extract the predictor and response variables

# Fit a robust linear regression model to the data using the Huber estimator
model = smf.RLM(y, x, M=smf.robust.norms.HuberT()).fit()

# Print the coefficients and intercept of the model
print(f'Coefficients: {model.params}')
print(f'Intercept: {model.params[0]}')

# Calculate the predicted values
y_pred = model.predict(x)

# Calculate the adjusted R^2 value
n = len(y)  # number of observations
p = x.shape[1]  # number of predictor variables
r_adj = 1 - (1 - r2) * (n - 1) / (n - p - 1)
print(f'Adjusted R^2 = {r_adj:.2f}')
# Out:
# Coefficients: [1.0397965]
# Intercept: 1.0397965017302067
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19824/2378449563.py in <module>
#      21 n = len(y)  # number of observations
#      22 p = x.shape[1]  # number of predictor variables
# ---> 23 r_adj = 1 - (1 - r2) * (n - 1) / (n - p - 1)
#      24 print(f'Adjusted R^2 = {r_adj:.2f}')
#      25
#
# NameError: name 'r2' is not defined

# %%
conda install -c r r-robustreg
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\gulsh\anaconda3
#
#   added / updated specs:
#     - r-robustreg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _r-mutex-1.0.0             |      anacondar_1           3 KB
#     m2w64-bwidget-1.9.10       |                2         153 KB
#     m2w64-bzip2-1.0.6          |                6         100 KB
#     m2w64-expat-2.1.1          |                2         160 KB
#     m2w64-fftw-3.3.4           |                6         5.4 MB
#     m2w64-flac-1.3.1           |                3         872 KB
#     m2w64-gettext-0.19.7       |                2         4.2 MB
#     m2w64-gsl-2.1              |                2         2.4 MB
#     m2w64-libiconv-1.14        |                6         1.5 MB
#     m2w64-libjpeg-turbo-1.4.2  |                3         656 KB
# ...

# %%
pip install robustreg
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement robustreg (from versions: none)
# ERROR: No matching distribution found for robustreg

# %%
# Import necessary libraries
import pandas as pd
import statsmodels.api.RLM as sm

# Load the data into a dataframe
# df = pd.read_csv('data.csv')

# Extract the predictor and response variables
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data using the Huber estimator
model = sm.RLM(y, x, M=sm.robust.norms.HuberT()).fit()

# Print the coefficients and intercept of the model
print(f'Coefficients: {model.params}')
print(f'Intercept: {model.params[0]}')

# Calculate the predicted values
y_pred = model.predict(x)

# Calculate the R^2 value
r2_adj = model.rsquared_adj
print(f'Adjusted R^2 = {r2_adj:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19824/654471231.py in <module>
#       1 # Import necessary libraries
#       2 import pandas as pd
# ----> 3 import statsmodels.api.RLM as sm
#       4
#       5 # Load the data into a dataframe
#
# ModuleNotFoundError: No module named 'statsmodels.api.RLM'; 'statsmodels.api' is not a package

# %%
# Install the robustreg library
# !pip install robustreg

# Import necessary libraries
import pandas as pd
import robustreg

# Load the data into a dataframe
# df = pd.read_csv('data.csv')

# Extract the predictor and response variables
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data
model = robustreg.RobustLinearRegression().fit(x, y)

# Calculate the predicted values
y_pred = model.predict(x)

# Calculate the R^2 value
r2 = model.score(x, y)
print(f'R^2 = {r2:.2f}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22712/4249781978.py in <module>
#       4 # Import necessary libraries
#       5 import pandas as pd
# ----> 6 import robustreg
#       7
#       8 # Load the data into a dataframe
#
# ModuleNotFoundError: No module named 'robustreg'

# %%
# Import necessary libraries
import pandas as pd
from sklearn.linear_model import HuberRegressor

# Load the data into a dataframe
# df = pd.read_csv('data.csv')

x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data using the HuberRegressor class
model = HuberRegressor().fit(x, y)

# Calculate the predicted values
y_pred = model.predict(x)

# Calculate the R^2 value
r2 = model.score(x, y)
print(f'R^2 = {r2:.2f}')
# Out:
# R^2 = 0.60

# %%
# Import necessary libraries
import pandas as pd
from sklearn.linear_model import TheilSenRegressor

# Load the data into a dataframe
# df = pd.read_csv('data.csv')

x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data using the TheilSenRegressor class
model = TheilSenRegressor().fit(x, y)

# Calculate the predicted values
y_pred = model.predict(x)

# Calculate the R^2 value
r2 = model.score(x, y)
print(f'R^2 = {r2:.2f}')
# Out:
# R^2 = 0.60

# %%
# Import necessary libraries
import pandas as pd
import statsmodels.api as sm

# Load the data into a dataframe
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data using the RLM function
model = sm.RLM(y, x, M=sm.robust.norms.HuberT()).fit()

# Calculate the adjusted R^2 value
r2_adj = model.rsquared_adj
print(f'Adjusted R^2 = {r2_adj:.2f}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22712/1142435330.py in <module>
#      11
#      12 # Calculate the adjusted R^2 value
# ---> 13 r2_adj = model.rsquared_adj
#      14 print(f'Adjusted R^2 = {r2_adj:.2f}')
#      15
#
# ~\anaconda3\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'RLMResults' object has no attribute 'rsquared_adj'

# %%
import statsmodels.api as sm
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values
model=sm.RLM(y,x).fit()
model.
# print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22712/2636775985.py in <module>
#       3 y = ndf['BAMPM2.5'].values
#       4 model=sm.RLM(y,x).fit()
# ----> 5 result=model.rsquare
#       6 print(result)
#       7 # print(model.summary())
#
# ~\anaconda3\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'RLMResults' object has no attribute 'rsquare'

# %%
# Import necessary libraries
import pandas as pd
import statsmodels.regression.linear_model as sm
import statsmodels.robust.norms as norms

# Load the data into a dataframe
x = ndf['S1'].values.reshape(-1, 1)
y = ndf['BAMPM2.5'].values

# Fit a robust linear regression model to the data using the RLM function
model = sm.RLM(y, x, M=norms.HuberT()).fit()

# Calculate the R^2 value
r2 = model.score(x, y)
print(f'R^2 = {r2:.2f}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22712/3482445033.py in <module>
#       9
#      10 # Fit a robust linear regression model to the data using the RLM function
# ---> 11 model = sm.RLM(y, x, M=norms.HuberT()).fit()
#      12
#      13 # Calculate the R^2 value
#
# AttributeError: module 'statsmodels.regression.linear_model' has no attribute 'RLM'

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Read data from a csv
df = pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one_outer.xlsx")
df = df.dropna()

# Extract data from columns
x = df['AT']
y = df['AH']
z = df['S1']

# Create a meshgrid
x_unique = np.unique(x)
y_unique = np.unique(y)
X, Y = np.meshgrid(x_unique, y_unique)

# Reshape the z values to match the meshgrid shape
if len(x_unique) * len(y_unique) == len(z):
    Z = z.reshape((len(y_unique), len(x_unique)))
else:
    print('Error: the shape of z does not match the shape of the meshgrid')
    Z = np.zeros((len(y_unique), len(x_unique)))

# Create the surface plot
fig = go.Figure(data=[go.Surface(z=Z, x=X, y=Y)])

# Set the axis labels
fig.update_layout(scene=dict(xaxis_title='Reference Sensor', yaxis_title='Humidity', zaxis_title='Temperature'))

# Show the figure
fig.show()
# Out:
# Error: the shape of z does not match the shape of the meshgrid
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Read data from a csv
df = pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one_outer.xlsx")
df = df.dropna()

# Extract data from columns
x = df['AT']
y = df['AH']
z = df['S1']

# Create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(x, y, z, cmap='viridis', edgecolor='none')
# Create a meshgrid from x and y
# x_unique = np.unique(x)
# y_unique = np.unique(y)
# X, Y = np.meshgrid(x_unique, y_unique)

# # Reshape the z values to match the meshgrid shape
# Z = z.values.reshape((len(y_unique), len(x_unique)))

# # Create the surface plot
# ax.plot_surface(X, Y, Z, cmap='viridis')

# Set the axis labels
ax.set_xlabel('Reference Sensor')
ax.set_ylabel('Humidity')
ax.set_zlabel('Temperature')

# Show the plot
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Read data from a csv
df = pd.read_excel("D:/air quality/OneDrive - design.iitd.ac.in/Desktop/New folder/Jodhpur data/one_outer.xlsx")
df = df.dropna()

# Create the 3D surface plot
fig = px.scatter_3d(df, x='AT', y='AH', z='S1', color='S1', opacity=0.8)

# Set the axis labels
fig.update_layout(scene=dict(xaxis_title='Reference Sensor', yaxis_title='Humidity', zaxis_title='Temperature'))

# Show the figure
fig.show()
# Out:
# <div>                            <div id="842ad24f-fd6d-4697-8d9b-0c133ec0b48a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("842ad24f-fd6d-4697-8d9b-0c133ec0b48a")) {                    Plotly.newPlot(                        "842ad24f-fd6d-4697-8d9b-0c133ec0b48a",                        [{"hovertemplate":"AT=%{x}<br>AH=%{y}<br>S1=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[28.75,31.0,44.5,60.0,62.66666666666666,91.66666666666667,78.0,72.0,66.0,66.0,37.33333333333334,36.0,32.33333333333334,31.0,48.0,43.0,93.0,56.0,46.0,36.0,38.66666666666666,54.33333333333334,58.0,61.0,63.66666666666666,63.5,68.5,82.0,88.66666666666667,94.5,92.25,106.6666666666667,73.25,57.33333333333334,49.33333333333334,45.66666666666666,37.0,35.0,45.75,4
# ...
